# %% [markdown]
# # Adquisición y Procesamiento de Datos
#
# Aplicar técnicas de adquisición de datos desde distintas fuentes:
#
# - **JSON**
# - **XML**
# - **Excel**
# - **Scraping web**
# - **Base de datos relacional**
#
# El objetivo es procesar, transformar y diseñar un **modelo estrella**, culminando con la **visualización de los datos en un dashboard interactivo**.

# %% [markdown]
# Recolección de los datos del 2024 en distintas fuentes y zonas de Panamá:
# - export.csv from https://meteostat.net/es/station/78792?t=2025-01-01/2025-01-31 TOCUMEN
# - webscraping from https://www.imhpa.gob.pa/es/datos-diarios?estacion=1&mes=1&ano=2025 David Chiriquí
# - XML Santiago
# - JSON Bocas del Toro
